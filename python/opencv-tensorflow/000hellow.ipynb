# %%
# import
import tensorflow as tf
hello = tf.constant('hello world')
sess = tf.Session()
print(sess.run(hello))
# Out:
# b'hello world'

# %%
import cv2
print('hello opencv')
# Out:
# hello opencv
